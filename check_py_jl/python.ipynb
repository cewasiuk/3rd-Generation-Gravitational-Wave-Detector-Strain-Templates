# %%
import sys
import os
import numpy as np
import pickle

# Add parent directory to path to import julia_strain_functions
# sys.path.append(os.path.abspath(os.path.join(os.path.dirname(__file__), '..')))
sys.path.append('..')  # or use relative path

import julia_strain_functions as jsf

# %%
alpha = 1.0
omega_tr = 8.166259544685282e-16
M = 1.11544991405595e+51
gamma_t_ne_GeV = jsf.gamma_t_6g_to_5g(alpha, omega_tr, M)
print("\n gamma_t_ne_GeV =", gamma_t_ne_GeV)
# Out:
#  gamma_t_ne_GeV = 4.664770779926167e-84

# %%
r_g = jsf.G * M
C = (2**28 * 3**4 * 5**5) / (11**22 * np.pi) * (32*np.pi/15.0) 
# C *= (32*np.pi/15.0)   # ∫ sin^4θ dΩ
P_t = C * (jsf.G * alpha**12) / (r_g**4)

# %%
r_g, C, P_t
# Out:
# (7483366255592.881, 1.7807156064366866e-09, 3.8093728905341066e-99)

# %%
l = 3
for k in range(1, l + 1):
    print(k)
# Out:
# 1
# 2
# 3

# %%
(1-
-1)
# Out:
# 2
