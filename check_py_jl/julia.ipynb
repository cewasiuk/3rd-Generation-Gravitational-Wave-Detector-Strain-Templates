# %%
include("../julia_strain_functions.jl")
# Out:
# iso_gatom_ann_strain

# %%
alpha = 1.0
omega_tr = 8.166259544685282e-16
M = 1.11544991405595e+51
gamma_t_ne_GeV = gamma_t_6g_to_5g(alpha, omega_tr, M)
print("\n gamma_t_ne_GeV =", gamma_t_ne_GeV)
# Out:
#  gamma_t_ne_GeV =-1.389809368700234e-79

# %%
r_g = G * M
C = (2. ^28 * 3. ^4 * 5. ^5) / (11. ^22 * π) * (32. *π/15.0)
#C *= (32*π/15.0)   # ∫ sin^4θ dΩ
P_t = C * (G * alpha^12) / (r_g^4)

r_g, C, P_t
# Out:
# (7.483366255592881e12, 1.7807156064366866e-9, 3.8093728905341066e-99)

# %%
l = 3
for k in 1:l
    println(k)
end
# Out:
# 1
# 2
# 3

# %%
(1-
-1)
# Out:
# 2
