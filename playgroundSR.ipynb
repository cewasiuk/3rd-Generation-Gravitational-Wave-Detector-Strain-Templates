# %%
omega_tr = 8.166259544685282e-16
gamma_t = 4.664770779926167e-84
Ng = 2.727939095048373e+58 , Ne = 2.617984233922238e+58
G = 6.708832159377011e-39 , dist = 1.56e+36

# %%
omega_tr = 8.166259544685282e-16
gamma_t = -1.389809368700234e-79
Ng = 1.0090295510584073, Ne = 1.0095576403152011
G = 6.708832159377011e-39, dist = 1.56e36

# %%
Pkg.add("LsqFit")
# Out:
#    Resolving package versions...
#     Updating `~/bosonSR_repo_/Project.toml`
#   [2fda8390] + LsqFit v0.15.1
#     Updating `~/bosonSR_repo_/Manifest.toml`
#   [47edcb42] + ADTypes v1.20.0
#   [4fba245c] + ArrayInterface v7.22.0
#   [bbf7d656] + CommonSubexpressions v0.3.1
#   [163ba53b] + DiffResults v1.1.0
#   [b552c78f] + DiffRules v1.15.1
#   [a0c0ee7d] + DifferentiationInterface v0.7.12
#   [6a86dc24] + FiniteDiff v2.29.0
#   [f6369f11] + ForwardDiff v1.3.0
#   [2fda8390] + LsqFit v0.15.1
#   [d41bc354] + NLSolversBase v7.10.0
#   [efcf1570] + Setfield v1.1.2
#   [9fa8497b] + Future v1.11.0
# Precompiling project...
#    1019.1 ms  ✓ FiniteDiff
#    1228.1 ms  ✓ DifferentiationInterface
#     668.5 ms  ✓ Unitful → ForwardDiffExt
#     539.2 ms  ✓ DifferentiationInterface → DifferentiationInterfaceChainRulesCoreExt
#     553.2 ms  ✓ DifferentiationInterface → DifferentiationInterfaceFiniteDiffExt
#     617.5 ms  ✓ FiniteDiff → FiniteDiffSparseArraysExt
# ...

# %%
using Pkg
Pkg.activate(".")
Pkg.add("Pickle")
# Out:
#   Activating project at `~/bosonSR_repo_`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed StridedViews ─────────── v0.4.1
#    Installed MappedArrays ─────────── v0.4.3
#    Installed ZipFile ──────────────── v0.10.1
#    Installed StringEncodings ──────── v0.3.7
#    Installed QOI ──────────────────── v1.0.2
#    Installed Unitful ──────────────── v1.27.0
#    Installed JSON ─────────────────── v1.3.0
#    Installed StatsBase ────────────── v0.34.9
#    Installed PackageExtensionCompat ─ v1.0.2
#    Installed ComputePipeline ──────── v0.1.6
#    Installed Pickle ───────────────── v0.3.6
#    Installed libpng_jll ───────────── v1.6.53+0
#    Installed Glib_jll ─────────────── v2.86.2+0
#    Installed InternedStrings ──────── v0.7.0
#    Installed StructUtils ──────────── v2.6.0
#    Installed DelaunayTriangulation ── v1.6.6
#     Updating `~/bosonSR_repo_/Project.toml`
#   [fbb45041] + Pickle v0.3.6
# ...
